# %% [markdown]
# # Wireframe Magazine #
# [Github Repo - Main](https://github.com/Wireframe-Magazine)

# %% [markdown]
# # Wireframe Magazine #1
# [Github Repo - Main](https://github.com/Wireframe-Magazine)
#
# [Explosions](https://github.com/Wireframe-Magazine/Wireframe-1)

# %%
import random

# %%
rgb = int(random.uniform(128,255)), int(random.uniform(128,255)), int(random.uniform(128,255))

# %%
print(rgb)
# Out:
# (217, 179, 249)

# %%
def fade(input):
    fd = input[0]/180, input[1]/180, input[2]/180
    for i in range(180):
        print(input, fd)
#         input = round(input[0]-fd[0]), round(input[1]-fd[1]), round(input[2]-fd[2])
        input = input[0]-fd[0], input[1]-fd[1], input[2]-fd[2]

# %%
fade(rgb)
# Out:
# (217, 179, 249) (1.2055555555555555, 0.9944444444444445, 1.3833333333333333)
# (215.79444444444445, 178.00555555555556, 247.61666666666667) (1.2055555555555555, 0.9944444444444445, 1.3833333333333333)
# (214.5888888888889, 177.01111111111112, 246.23333333333335) (1.2055555555555555, 0.9944444444444445, 1.3833333333333333)
# (213.38333333333335, 176.01666666666668, 244.85000000000002) (1.2055555555555555, 0.9944444444444445, 1.3833333333333333)
# (212.1777777777778, 175.02222222222224, 243.4666666666667) (1.2055555555555555, 0.9944444444444445, 1.3833333333333333)
# (210.97222222222226, 174.0277777777778, 242.08333333333337) (1.2055555555555555, 0.9944444444444445, 1.3833333333333333)
# (209.7666666666667, 173.03333333333336, 240.70000000000005) (1.2055555555555555, 0.9944444444444445, 1.3833333333333333)
# (208.56111111111116, 172.03888888888892, 239.31666666666672) (1.2055555555555555, 0.9944444444444445, 1.3833333333333333)
# ...
